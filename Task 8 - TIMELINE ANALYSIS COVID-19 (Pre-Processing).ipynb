# %% [markdown]
# ## AUTHOR: Trakshay Balagotra
#
# **Task 8 - TIMELINE ANALYSIS COVID-19**
#
# **@SPARKS FOUNDATION**
#
# **Pre-Processing data to visualize the factors involved in COVID-19.**

# %% [markdown]
# ## DECLARING LIBRARY

# %%
import pandas as pd

# %% [markdown]
# ## LOADING DATASET

# %%
covid= pd.read_csv('owid-covid-data.csv')

# %%
covid
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 73173      ZWE    Africa     Zimbabwe  2021-03-02      36148.0       33.0
# 73174      ZWE    Africa     Zimbabwe  2021-03-03      36179.0       31.0
# 73175      ZWE    Africa     Zimbabwe  2021-03-04      36223.0       44.0
# 73176      ZWE    Africa     Zimbabwe  2021-03-05      36248.0       25.0
# 73177      ZWE    Africa     Zimbabwe  2021-03-06      36260.0       12.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         NaN                  NaN  ...
# 1                     NaN           NaN         NaN                  NaN  ...
# 2                     NaN           NaN         NaN                  NaN  ...
# 3                     NaN           NaN         NaN                  NaN  ...
# 4                     NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 73173              34.000        1472.0         4.0                3.429  ...
# 73174              31.286        1478.0         6.0                3.143  ...
# 73175              32.714        1483.0         5.0                3.571  ...
# 73176              29.143        1484.0         1.0                3.000  ...
# 73177              28.857        1485.0         1.0                3.143  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# 2            1803.987              NaN                597.029
# 3            1803.987              NaN                597.029
# 4            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 73173        1899.775             21.4                307.846
# 73174        1899.775             21.4                307.846
# 73175        1899.775             21.4                307.846
# 73176        1899.775             21.4                307.846
# 73177        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# 2                     9.59             NaN           NaN
# 3                     9.59             NaN           NaN
# 4                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 73173                 1.82             1.6          30.7
# 73174                 1.82             1.6          30.7
# 73175                 1.82             1.6          30.7
# 73176                 1.82             1.6          30.7
# 73177                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# 2                      37.746                         0.5            64.83
# 3                      37.746                         0.5            64.83
# 4                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 73173                  36.791                         1.7            61.49
# 73174                  36.791                         1.7            61.49
# 73175                  36.791                         1.7            61.49
# 73176                  36.791                         1.7            61.49
# 73177                  36.791                         1.7            61.49
#
#        human_development_index
# 0                        0.511
# 1                        0.511
# 2                        0.511
# 3                        0.511
# 4                        0.511
# ...                        ...
# 73173                    0.571
# 73174                    0.571
# 73175                    0.571
# 73176                    0.571
# 73177                    0.571
#
# [73178 rows x 59 columns]

# %% [markdown]
# ## CLEANING DATA

# %%
# Only Extracting those columns which have only upto 20% value missing
cols = covid.columns[covid.isna().sum()/len(covid) <= 0.2]
covid_df = covid[cols]
covid_df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 73173      ZWE    Africa     Zimbabwe  2021-03-02      36148.0       33.0
# 73174      ZWE    Africa     Zimbabwe  2021-03-03      36179.0       31.0
# 73175      ZWE    Africa     Zimbabwe  2021-03-04      36223.0       44.0
# 73176      ZWE    Africa     Zimbabwe  2021-03-05      36248.0       25.0
# 73177      ZWE    Africa     Zimbabwe  2021-03-06      36260.0       12.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         NaN                  NaN  ...
# 1                     NaN           NaN         NaN                  NaN  ...
# 2                     NaN           NaN         NaN                  NaN  ...
# 3                     NaN           NaN         NaN                  NaN  ...
# 4                     NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 73173              34.000        1472.0         4.0                3.429  ...
# 73174              31.286        1478.0         6.0                3.143  ...
# 73175              32.714        1483.0         5.0                3.571  ...
# 73176              29.143        1484.0         1.0                3.000  ...
# 73177              28.857        1485.0         1.0                3.143  ...
#
#        population_density  median_age  aged_65_older  aged_70_older  \
# 0                  54.422        18.6          2.581          1.337
# 1                  54.422        18.6          2.581          1.337
# 2                  54.422        18.6          2.581          1.337
# 3                  54.422        18.6          2.581          1.337
# 4                  54.422        18.6          2.581          1.337
# ...                   ...         ...            ...            ...
# 73173              42.729        19.6          2.822          1.882
# 73174              42.729        19.6          2.822          1.882
# 73175              42.729        19.6          2.822          1.882
# 73176              42.729        19.6          2.822          1.882
# 73177              42.729        19.6          2.822          1.882
#
#        gdp_per_capita  cardiovasc_death_rate  diabetes_prevalence  \
# 0            1803.987                597.029                 9.59
# 1            1803.987                597.029                 9.59
# 2            1803.987                597.029                 9.59
# 3            1803.987                597.029                 9.59
# 4            1803.987                597.029                 9.59
# ...               ...                    ...                  ...
# 73173        1899.775                307.846                 1.82
# 73174        1899.775                307.846                 1.82
# 73175        1899.775                307.846                 1.82
# 73176        1899.775                307.846                 1.82
# 73177        1899.775                307.846                 1.82
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                             0.5            64.83                    0.511
# 1                             0.5            64.83                    0.511
# 2                             0.5            64.83                    0.511
# 3                             0.5            64.83                    0.511
# 4                             0.5            64.83                    0.511
# ...                           ...              ...                      ...
# 73173                         1.7            61.49                    0.571
# 73174                         1.7            61.49                    0.571
# 73175                         1.7            61.49                    0.571
# 73176                         1.7            61.49                    0.571
# 73177                         1.7            61.49                    0.571
#
# [73178 rows x 29 columns]

# %%
covid_df.dropna(inplace=True)
# Out:
# C:\Users\traksh3.0\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## CREATING CLEAN DATASET

# %%
covid_df.to_csv('Covid-19.csv', index=False)
